# %%
#Lipinski Rules
Molecule = "Mangiferin"
MW = 422.34 #g/mol
HBD = 8
HDA = 11
LogP = 0.45

Rule_passed = 0

if (MW <= 500):
    Rule_passed += 1
    print ("Passed")
else:
    print ("Failed")
if (HBD <= 5):
    Rule_passed += 1
    print ("Passed")
else:
    print ("Failed")
if (HDA <= 10):
    Rule_passed += 1
    print ("Passed")
else:
    print ("Failed")
if (LogP <= 5):
    Rule_passed += 1
    print ("Passed")
else:
    print ("Failed")
print ("Likely good oral bioavailabily") if Rule_passed >= 3 else print ("Likely poor oral bioavailabily")
# Out:
# Passed
# Failed
# Failed
# Passed
# Likely poor oral bioavailabily
